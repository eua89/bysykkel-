# %%
#from BeautifulSoup import BeautifulSoup
from bs4 import BeautifulSoup
import urllib.request

url = 'https://developer.oslobysykkel.no/data'
r = urllib.request.urlopen(url).read()
soup = BeautifulSoup(r)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Oslo City Bike developer
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"161028c578","applicationID":"29219655","transactionName":"IF1fEUANX1RVQUpHFgpCbgBKElxKREBKWgoHV0k=","queueTime":2,"applicationTime":30,"agent":""}
#   </script>
#   <script type="text/javascript">
# ...

# %%
values= [row.get('href') for row in soup.findAll('a', {"class":'button'})]
print (values)
# Out:
# ['/data/26.json', '/data/26.csv', '/data/25.json', '/data/25.csv', '/data/24.json', '/data/24.csv', '/data/23.json', '/data/23.csv', '/data/22.json', '/data/22.csv', '/data/21.json', '/data/21.csv', '/data/20.json', '/data/20.csv', '/data/19.json', '/data/19.csv', '/data/18.json', '/data/18.csv', '/data/16.json', '/data/16.csv', '/data/15.json', '/data/15.csv', '/data/14.json', '/data/14.csv', '/data/13.json', '/data/13.csv', '/data/12.json', '/data/12.csv', '/data/11.json', '/data/11.csv', '/data/10.json', '/data/10.csv', '/data/9.json', '/data/9.csv', '/data/8.json', '/data/8.csv']

# %%
import re
def make_url(ending):
    beginning ='https://developer.oslobysykkel.no/data'
    return beginning+'/'+ending.split('/')[2]

total_link=[make_url(ending) for ending in values if re.search(".json", ending)]
print (total_link)
# Out:
# ['https://developer.oslobysykkel.no/data/26.json', 'https://developer.oslobysykkel.no/data/25.json', 'https://developer.oslobysykkel.no/data/24.json', 'https://developer.oslobysykkel.no/data/23.json', 'https://developer.oslobysykkel.no/data/22.json', 'https://developer.oslobysykkel.no/data/21.json', 'https://developer.oslobysykkel.no/data/20.json', 'https://developer.oslobysykkel.no/data/19.json', 'https://developer.oslobysykkel.no/data/18.json', 'https://developer.oslobysykkel.no/data/16.json', 'https://developer.oslobysykkel.no/data/15.json', 'https://developer.oslobysykkel.no/data/14.json', 'https://developer.oslobysykkel.no/data/13.json', 'https://developer.oslobysykkel.no/data/12.json', 'https://developer.oslobysykkel.no/data/11.json', 'https://developer.oslobysykkel.no/data/10.json', 'https://developer.oslobysykkel.no/data/9.json', 'https://developer.oslobysykkel.no/data/8.json']

# %%
import wget

for i,link in enumerate(total_link):
    wget.download(link, 'file_{}.zip'.format(i))

# %%
import os,zipfile

dir_name = os.getcwd()+'/'
extension = '.zip'

for item in os.listdir(dir_name):
    if item.endswith(extension):
        file_name = dir_name + item
        try:
            zip_ref = zipfile.ZipFile(file_name) 
            zip_ref.extractall(dir_name) 
            zip_ref.close() 
            os.remove(file_name) 
        except:
            pass
